# %%
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
riders = pd.read_csv("riders.csv")

# %%
riders.shape
# Out:
# (960, 5)

# %%
riders.describe()
# Out:
#        No_Of_Orders          Age  Average_Rating  No_of_Ratings
# count    960.000000   960.000000      960.000000     960.000000
# mean    1864.851042  1200.234375       13.412604     427.983333
# std     1880.337785   810.930171        2.675794     486.957931
# min        2.000000    96.000000        0.000000       0.000000
# 25%      261.750000   478.250000       13.500000      30.000000
# 50%     1475.500000  1021.000000       14.000000     223.000000
# 75%     2847.250000  1891.500000       14.300000     678.750000
# max     9756.000000  3764.000000       15.200000    2298.000000

# %%
riders.columns
# Out:
# Index(['Rider Id', 'No_Of_Orders', 'Age', 'Average_Rating', 'No_of_Ratings'], dtype='object')

# %%
riders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rider Id        960 non-null    object
#  1   No_Of_Orders    960 non-null    int64
#  2   Age             960 non-null    int64
#  3   Average_Rating  960 non-null    float64
#  4   No_of_Ratings   960 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 37.6+ KB

# %%
riders.isnull()
riders.isnull().sum()
# Out:
# Rider Id         0
# Orders           0
# Age              0
# Avg_Rating       0
# No_of_Ratings    0
# dtype: int64

# %%
riders.rename(columns={'No_Of_Orders':'Orders', 'Average_Rating':'Avg_Rating'}, inplace=True)
riders.head()
# Out:
#        Rider Id  Orders   Age  Avg_Rating  No_of_Ratings
# 0  Rider_Id_396    2946  2298        14.0           1159
# 1  Rider_Id_479     360   951        13.5            176
# 2  Rider_Id_648    1746   821        14.3            466
# 3  Rider_Id_753     314   980        12.5             75
# 4  Rider_Id_335     536  1113        13.7            156

# %%
sns.distplot(riders.Orders, bins=20, kde=False, rug=True)

# %%
sns.distplot(riders.Age, bins=20, kde=False, rug=True)

# %%
sns.distplot(riders.Avg_Rating, bins=20, kde=False, rug=True)

# %%
sns.distplot(riders.No_of_Ratings, bins=20, kde=False, rug=True)

# %%
riders[riders.Avg_Rating < 10]
# Out:
#          Rider Id  Orders   Age  Avg_Rating  No_of_Ratings
# 213  Rider_Id_417       5   875         0.0              1
# 392  Rider_Id_552      15   698         0.0              0
# 488  Rider_Id_897       2   576         0.0              1
# 497    Rider_Id_1       8   589         0.0              1
# 517  Rider_Id_867      32   587         0.0              0
# 628  Rider_Id_918      39   488         6.0              2
# 630  Rider_Id_667       4   488         0.0              1
# 648   Rider_Id_47      29   463         0.0              0
# 661  Rider_Id_220       9   452         0.0              1
# 674  Rider_Id_957      11   419         0.0              1
# 702  Rider_Id_556       4   378         0.0              1
# 722  Rider_Id_947      65   379         3.0              6
# 767  Rider_Id_529       3   307         0.0              1
# 769   Rider_Id_44       9   307         0.0              1
# 771   Rider_Id_59      32   336         0.0              1
# ...

# %%
ax = sns.lmplot(x="Orders", y="No_of_Ratings", data=riders)

# %%
ax = sns.scatterplot(x="Orders", y="No_of_Ratings", data=riders, hue="Avg_Rating")

# %%
ax = sns.scatterplot(x="Age", y="Avg_Rating", data=riders, hue="No_of_Ratings")
